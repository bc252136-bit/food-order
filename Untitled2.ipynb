# %% [markdown]
# <a href="https://colab.research.google.com/github/bc252136-bit/food-order/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Data manipulation
import pandas as pd
import numpy as np

# Data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Data preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Machine Learning Models
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# Evaluation
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    classification_report
)

# %%
df = pd.read_csv("/content/food_order.csv")

# Display first 5 rows
df.head()
# Out:
#    order_id  customer_id            restaurant_name cuisine_type  \
# 0   1477147       337525                    Hangawi       Korean
# 1   1477685       358141  Blue Ribbon Sushi Izakaya     Japanese
# 2   1477070        66393                Cafe Habana      Mexican
# 3   1477334       106968  Blue Ribbon Fried Chicken     American
# 4   1478249        76942           Dirty Bird to Go     American
#
#    cost_of_the_order day_of_the_week     rating  food_preparation_time  \
# 0              30.75         Weekend  Not given                     25
# 1              12.08         Weekend  Not given                     25
# 2              12.23         Weekday          5                     23
# 3              29.20         Weekend          3                     25
# 4              11.59         Weekday          4                     25
#
#    delivery_time
# 0             20
# 1             23
# 2             28
# 3             15
# 4             24

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1898 entries, 0 to 1897
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   order_id               1898 non-null   int64
#  1   customer_id            1898 non-null   int64
#  2   restaurant_name        1898 non-null   object
#  3   cuisine_type           1898 non-null   object
#  4   cost_of_the_order      1898 non-null   float64
#  5   day_of_the_week        1898 non-null   object
#  6   rating                 1898 non-null   object
#  7   food_preparation_time  1898 non-null   int64
#  8   delivery_time          1898 non-null   int64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 133.6+ KB

# %%
print("Rows and Columns:", df.shape)
# Out:
# Rows and Columns: (1898, 9)

# %%
df.describe()
# Out:
#            order_id    customer_id  cost_of_the_order  food_preparation_time  \
# count  1.898000e+03    1898.000000        1898.000000            1898.000000
# mean   1.477496e+06  171168.478398          16.498851              27.371970
# std    5.480497e+02  113698.139743           7.483812               4.632481
# min    1.476547e+06    1311.000000           4.470000              20.000000
# 25%    1.477021e+06   77787.750000          12.080000              23.000000
# 50%    1.477496e+06  128600.000000          14.140000              27.000000
# 75%    1.477970e+06  270525.000000          22.297500              31.000000
# max    1.478444e+06  405334.000000          35.410000              35.000000
#
#        delivery_time
# count    1898.000000
# mean       24.161749
# std         4.972637
# min        15.000000
# 25%        20.000000
# 50%        25.000000
# 75%        28.000000
# max        33.000000

# %%
df.dtypes
# Out:
# order_id                   int64
# customer_id                int64
# restaurant_name           object
# cuisine_type              object
# cost_of_the_order        float64
# day_of_the_week           object
# rating                    object
# food_preparation_time      int64
# delivery_time              int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# order_id                 0
# customer_id              0
# restaurant_name          0
# cuisine_type             0
# cost_of_the_order        0
# day_of_the_week          0
# rating                   0
# food_preparation_time    0
# delivery_time            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df['rating'].fillna(df['rating'].mode()[0], inplace=True)
# Out:
# /tmp/ipykernel_1242/2284108631.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['rating'].fillna(df['rating'].mode()[0], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1898 entries, 0 to 1897
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   order_id               1898 non-null   int64
#  1   customer_id            1898 non-null   int64
#  2   restaurant_name        1898 non-null   object
#  3   cuisine_type           1898 non-null   object
#  4   cost_of_the_order      1898 non-null   float64
#  5   day_of_the_week        1898 non-null   object
#  6   rating                 1898 non-null   object
#  7   food_preparation_time  1898 non-null   int64
#  8   delivery_time          1898 non-null   int64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 133.6+ KB

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['cost_of_the_order'], bins=30)
plt.title("Distribution of Order Cost")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['delivery_time'], bins=20)
plt.title("Distribution of Delivery Time")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(
    y='cuisine_type',
    data=df,
    order=df['cuisine_type'].value_counts().index
)

plt.title("Cuisine Type Distribution")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='rating', data=df)

plt.title("Customer Ratings")
plt.show()

# %%
plt.figure(figsize=(8,6))

numeric = df.select_dtypes(include=['int64','float64'])

sns.heatmap(
    numeric.corr(),
    annot=True,
    cmap='coolwarm'
)

plt.title("Correlation Heatmap")
plt.show()

# %%
median_time = df['delivery_time'].median()

print("Median Delivery Time:", median_time)
# Out:
# Median Delivery Time: 25.0

# %%
df['delivery_status'] = df['delivery_time'].apply(
    lambda x: 'Fast' if x <= median_time else 'Late'
)

df[['delivery_time','delivery_status']].head()
# Out:
#    delivery_time delivery_status
# 0             20            Fast
# 1             23            Fast
# 2             28            Late
# 3             15            Fast
# 4             24            Fast

# %%
X = df[
    [
        'restaurant_name',
        'cuisine_type',
        'cost_of_the_order',
        'day_of_the_week',
        'food_preparation_time'
    ]
]

y = df['delivery_status']

# %%
X = pd.get_dummies(
    X,
    columns=[
        'restaurant_name',
        'cuisine_type',
        'day_of_the_week'
    ],
    drop_first=True
)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# %%
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)

X_test = scaler.transform(X_test)

# %%
dt = DecisionTreeClassifier(random_state=42)

dt.fit(X_train, y_train)

prediction_dt = dt.predict(X_test)

accuracy_dt = accuracy_score(y_test, prediction_dt)

print("Decision Tree Accuracy:", accuracy_dt)
# Out:
# Decision Tree Accuracy: 0.6263157894736842

# %%
from sklearn import tree
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))

tree.plot_tree(
    dt,
    feature_names=X.columns,
    class_names=dt.classes_,
    filled=True,
    rounded=True,
    fontsize=8
)

plt.title("Decision Tree Visualization")

plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/tree/_export.py:673: UserWarning: Glyph 142 (\x8e) missing from font(s) DejaVu Sans.
#   ann.update_bbox_position_size(renderer)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 142 (\x8e) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
rf = RandomForestClassifier(random_state=42)

rf.fit(X_train, y_train)

prediction_rf = rf.predict(X_test)

accuracy_rf = accuracy_score(y_test, prediction_rf)

print("Random Forest Accuracy:", accuracy_rf)
# Out:
# Random Forest Accuracy: 0.6605263157894737

# %%
knn = KNeighborsClassifier(n_neighbors=5)

knn.fit(X_train, y_train)

prediction_knn = knn.predict(X_test)

accuracy_knn = accuracy_score(y_test, prediction_knn)

print("KNN Accuracy:", accuracy_knn)
# Out:
# KNN Accuracy: 0.6289473684210526

# %%
print(classification_report(y_test, prediction_dt))
# Out:
#               precision    recall  f1-score   support
#
#         Fast       0.65      0.67      0.66       208
#         Late       0.59      0.57      0.58       172
#
#     accuracy                           0.63       380
#    macro avg       0.62      0.62      0.62       380
# weighted avg       0.63      0.63      0.63       380

# %%
cm_dt = confusion_matrix(y_test, prediction_dt)

plt.figure(figsize=(6,5))

sns.heatmap(
    cm_dt,
    annot=True,
    fmt='d',
    cmap='Blues'
)

plt.title("Decision Tree Confusion Matrix")

plt.xlabel("Predicted")

plt.ylabel("Actual")

plt.show()

# %%
print(classification_report(y_test, prediction_rf))
# Out:
#               precision    recall  f1-score   support
#
#         Fast       0.68      0.73      0.70       208
#         Late       0.64      0.58      0.61       172
#
#     accuracy                           0.66       380
#    macro avg       0.66      0.65      0.65       380
# weighted avg       0.66      0.66      0.66       380

# %%
cm_rf = confusion_matrix(y_test, prediction_rf)

plt.figure(figsize=(6,5))

sns.heatmap(
    cm_rf,
    annot=True,
    fmt='d',
    cmap='Greens'
)

plt.title("Random Forest Confusion Matrix")

plt.show()

# %%
importance = pd.DataFrame({
    'Feature': X.columns,
    'Importance': rf.feature_importances_
})

importance = importance.sort_values(
    by='Importance',
    ascending=False
)

plt.figure(figsize=(10,8))

plt.barh(
    importance['Feature'],
    importance['Importance']
)

plt.gca().invert_yaxis()

plt.title("Feature Importance")

plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 142 (\x8e) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 140 (\x8c) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
print(classification_report(y_test, prediction_knn))
# Out:
#               precision    recall  f1-score   support
#
#         Fast       0.65      0.71      0.68       208
#         Late       0.60      0.53      0.56       172
#
#     accuracy                           0.63       380
#    macro avg       0.62      0.62      0.62       380
# weighted avg       0.63      0.63      0.63       380

# %%
cm_knn = confusion_matrix(y_test, prediction_knn)

plt.figure(figsize=(6,5))

sns.heatmap(
    cm_knn,
    annot=True,
    fmt='d',
    cmap='Oranges'
)

plt.title("KNN Confusion Matrix")

plt.show()

# %%
print(classification_report(y_test, prediction_rf))
# Out:
#               precision    recall  f1-score   support
#
#         Fast       0.68      0.73      0.70       208
#         Late       0.64      0.58      0.61       172
#
#     accuracy                           0.66       380
#    macro avg       0.66      0.65      0.65       380
# weighted avg       0.66      0.66      0.66       380

# %%
accuracy = []

for k in range(1,21):

    model = KNeighborsClassifier(n_neighbors=k)

    model.fit(X_train,y_train)

    pred = model.predict(X_test)

    accuracy.append(
        accuracy_score(y_test,pred)
    )

plt.figure(figsize=(8,5))

plt.plot(range(1,21),accuracy,marker='o')

plt.xlabel("K Value")

plt.ylabel("Accuracy")

plt.title("Accuracy vs K Value")

plt.grid(True)

plt.show()

# %%
accuracy = []

for k in range(1,21):

    model = KNeighborsClassifier(n_neighbors=k)

    model.fit(X_train,y_train)

    pred = model.predict(X_test)

    accuracy.append(
        accuracy_score(y_test,pred)
    )

plt.figure(figsize=(8,5))

plt.plot(range(1,21),accuracy,marker='o')

plt.xlabel("K Value")

plt.ylabel("Accuracy")

plt.title("Accuracy vs K Value")

plt.grid(True)

plt.show()

# %%
comparison = pd.DataFrame({
    'Model':[
        'Decision Tree',
        'Random Forest',
        'KNN'
    ],
    'Accuracy':[
        accuracy_dt,
        accuracy_rf,
        accuracy_knn
    ]
})

comparison
# Out:
#            Model  Accuracy
# 0  Decision Tree  0.626316
# 1  Random Forest  0.660526
# 2            KNN  0.628947

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    data=comparison,
    x='Model',
    y='Accuracy'
)

plt.title("Machine Learning Model Comparison")

for index, value in enumerate(comparison['Accuracy']):
    plt.text(index, value, round(value,3), ha='center')

plt.show()
